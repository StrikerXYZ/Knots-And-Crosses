# %% [markdown]
# # **Knots And Crosses**
#
# Github: https://github.com/StrikerXYZ/Knots-And-Crosses

# %% [markdown]
# Environment:

# %%
import gym
import numpy as np
import random

class KnotsNCrosses(gym.Env):

  def __init__(self):
    self.done = False;
    self.observation = np.full((9), [' '],dtype=str);
    self.transitionTable = {}
    self.transitionTable[tuple(self.observation.copy())] = self.getDataForState(self.observation)
    self.valueTable = {}
    self.valueTable[tuple(self.observation.copy())] = [0.0, 0.0]
    self.policyTable = {}
    self.policyTable[tuple(self.observation.copy())] = [0.0, 0.0]
    self.playerTurn = random.choice([0,1])
    self.performValueIter = False

  def reset(self, isValueIter):
    self.done = False;
    self.observation = np.full((9), [' '],dtype=str);
    self.playerTurn = random.choice([0,1])
    self.performValueIter = isValueIter
    return self.observation;

  def getDataForState(self, observation):
    if not tuple(observation) in self.transitionTable:
      self.transitionTable[tuple(observation.copy())] = self.makeDataForAllActions(observation)
    return self.transitionTable[tuple(observation)]

  def makeDataForAllActions(self, observation):
    actions = self.getPossibleActions(observation)
    values = {}
    for i, action in enumerate(actions):
      values[action] = [self.getStateAfterAction(observation, action, 0), self.getStateAfterAction(observation, action, 1)]
    return values

  def getPossibleActions(self, observation):
    actions = []
    for i in range(9):
      if (observation[i] == ' '):
        actions.append(i)
    return actions

  def getStateAfterAction(self, observation, action, playerIndex):
    if (observation[action] == ' '):
      obs = observation.copy()
      obs[action] = self.playerMark(playerIndex);
      return obs
    return observation

  def playerMark(self, playerIndex):
    if (playerIndex == 0):
      return 'X'
    else:
      return 'O'

  def opponentMark(self, playerIndex):
    return self.playerMark(self.getNextPlayerIndex(playerindex))

  def getRewardForState(self, observation, playerIndex):
    if self.checkHorizontal(observation, playerIndex) or \
    self.checkVertical(observation, playerIndex) or \
    self.checkDiagonal(observation, playerIndex):
      return 2.0;

    opponentIndex = self.getNextPlayerIndex(playerIndex)
    if self.checkHorizontal(observation, opponentIndex) or \
    self.checkVertical(observation, opponentIndex) or \
    self.checkDiagonal(observation, opponentIndex):
      return -2.0;
    
    if len(self.getPossibleActions(observation)) == 0:
      return 1.0
    
    return 0.0;

  def checkHorizontal(self, observation, playerIndex):
    mark = self.playerMark(playerIndex)
    for i in range(3):
      count = 0
      for j in range(3):
        if observation[i*3 + j] == mark:
          count += 1
      if count == 3:
        return True
    return False
  
  def checkVertical(self, observation, playerIndex):
    mark = self.playerMark(playerIndex)
    for i in range(3):
      count = 0
      for j in range(3):
        if observation[j*3 + i] == mark:
          count += 1
      if count == 3:
        return True
    return False

  def checkDiagonal(self, observation, playerIndex):
    mark = self.playerMark(playerIndex)
    
    if observation[0] == mark and \
    observation[4] == mark and \
    observation[8] == mark:
      return True

    if observation[2] == mark and \
    observation[4] == mark and \
    observation[6] == mark:
      return True

    return False

  def policyIteration(self, playerIndex):
    isStable = False
    while (not isStable):
      self.policyEvaluation(playerIndex)
      isStable = self.policyImprovement(playerIndex)
    isStable = False

  def policyEvaluation(self, playerIndex):
    theta = 0.001
    gamma = 0.5
    while (True):
      diff = 0.0
      for s in self.transitionTable:
        value = self.getValueForObservation(np.asarray(s), playerIndex)
        newValue = self.getSumActionValueForObservation(np.asarray(s), playerIndex) + gamma * value
        self.valueTable[s][playerIndex] = newValue
        diff = max(diff, abs(newValue - value))
      if (diff < theta):
        break
      
  def policyImprovement(self, playerIndex):
    isStable = True
    for s in self.transitionTable:
      policy = self.getPolicyForObservation(np.asarray(s), playerIndex)
      newpolicy = self.getBestPolicyForObservation(np.asarray(s), playerIndex)
      self.policyTable[s][playerIndex] = newpolicy
      if (newpolicy != policy):
        isStable = False
    return isStable

  def valueIteration(self, playerIndex):
    gamma = 0.5
    for s in self.transitionTable:
      value = self.getValueForObservation(np.asarray(s), playerIndex)
      newValue = self.getSumActionValueForObservation(np.asarray(s), playerIndex) + gamma * value
      self.valueTable[s][playerIndex] = newValue
      policy = self.getPolicyForObservation(np.asarray(s), playerIndex)
      bestPolicy = self.getBestPolicyForObservation(np.asarray(s), playerIndex)
      self.policyTable[s][playerIndex] = bestPolicy

  def get_action_value(self, playerIndex):

    # Initialise Q 
    Q = 0  
    for s in mdp.get_all_states():
      # Compute Q using the equation above
      Q = Q + mdp.get_transition_prob(state, action, s)*(mdp.get_reward(state, action, s) + \
                                                               gamma*state_values[s]) 
    return Q

  def getValueForObservation(self, observation, playerIndex):
    if not tuple(observation) in self.valueTable:
      self.valueTable[tuple(observation)] = [self.getRewardForState(observation, 0), self.getRewardForState(observation, 1)]
    return self.valueTable[tuple(observation)][playerIndex]

  def getSumActionValueForObservation(self, observation, playerIndex):
    actions = self.transitionTable[tuple(observation)].copy()
    sumValue = 0
    for s in actions.values():
      value = self.getValueForObservation(s[playerIndex], playerIndex)
      sumValue += value
    return sumValue
    
  def getPolicyForObservation(self, observation, playerIndex):
    if not tuple(observation) in self.policyTable:
      firstAction = list(self.makeDataForAllActions(observation))[0]
      self.policyTable[tuple(observation)] = [firstAction, firstAction]
    return self.policyTable[tuple(observation)][playerIndex]

  def getBestPolicyForObservation(self, observation, playerIndex):
    actions = self.transitionTable[tuple(observation)]
    maxValue = None
    for a in actions:
      s = actions[a][playerIndex]
      v = self.getValueForObservation(s, playerIndex)
      if (not maxValue) or (maxValue < v):
        maxValue = v
        policy = a
    return policy

  def getNextPlayerIndex(self, playerIndex):
    return (playerIndex + 1) % 2

  def getRandomPolicy(self, observation):
    return np.random.choice(self.getPossibleActions(observation))

  def evaluateState(self, observation, playerIndex):
    if not self.done and not tuple(observation) in self.transitionTable:
      self.transitionTable[tuple(observation.copy())] = self.getDataForState(observation)

  def step(self, epsilon):
    if self.done:
      return

    if self.performValueIter:
      self.valueIteration(self.playerTurn)
    else:
      self.policyIteration(self.playerTurn)
    
    explore = np.random.uniform(0,1) < epsilon
    if explore:
      action = self.getRandomPolicy(self.observation)
    else:
      action = self.getPolicyForObservation(self.observation, self.playerTurn)

    self.observation = self.getStateAfterAction(self.observation, action, self.playerTurn)
    (done, winner) = self.isDone(self.observation)
    (rewardP1, rewardP2) = (0,0)

    if (done):
      rewardP1 = self.getRewardForState(self.observation, 0)
      rewardP2 = self.getRewardForState(self.observation, 1)
    else:
      self.evaluateState(self.observation, self.playerTurn)
      self.playerTurn = self.getNextPlayerIndex(self.playerTurn)

    self.done = done

    return done, winner, rewardP1, rewardP2;

  def isDone(self, observation):
    if self.getRewardForState(observation, 0) == 2:
      return (True, 1)
    if self.getRewardForState(observation, 1) == 2:
      return (True, 2)
    if len(self.getPossibleActions(observation)) == 0:
      return (True, 0)
    return (False, 0)

  def render(self):
        print(f'   |   |   ');
        print(f' {self.observation[0]} | {self.observation[1]} | {self.observation[2]} ');
        print(f'___|___|___');
        print(f'   |   |   ');
        print(f' {self.observation[3]} | {self.observation[4]} | {self.observation[5]} ');
        print(f'___|___|___');
        print(f'   |   |   ');
        print(f' {self.observation[6]} | {self.observation[7]} | {self.observation[8]} ');
        print(f'   |   |   \n');

def experiment(environment, numEpisodes, numIterations, isValueIteration):
  epsilon = 0.5
  decay = 0.99
  minEpsilon = 0.1

  (player1, player2, draws, player1Reward, player2Reward) = (0, 0, 0, 0, 0)
  for i in range(numEpisodes):
    print('Episode:', i)
    (done, winner, rewardP1, rewardP2) = runEpisode(environment, numIterations, epsilon, isValueIteration)
    
    if winner == 0: 
      draws += 1
    if winner == 1: 
      player1 += 1 
    if winner == 2: 
      player2 += 1
    
    player1Reward += rewardP1
    player2Reward += rewardP2

    epsilon = max(minEpsilon, epsilon * decay)
  print("Player1: ", player1, "Player2:", player2, "Wins:", player1 + player2, " Draws:", draws)
  print("Player1 Rewards: ", player1Reward, " Player2 Rewards:", player2Reward)
  print("Player1 Average: ", player1Reward/numIterations, " Player2 Average:", player2Reward/numIterations)

def runEpisode(environment, numIterations, epsilon, isValueIteration):
  environment.reset(isValueIteration)
  for _ in range(numIterations):
    (done, winner, rewardP1, rewardP2) = environment.step(epsilon)
    if done:
      environment.render()
      if winner != 0:
        print("winner: player", winner, '\n')
      else:
        print("draw\n")
      print("rewards:", rewardP1, rewardP2, '\n')
      return done, winner, rewardP1, rewardP2;

env = KnotsNCrosses()

# %% [markdown]
# Value Stats:

# %%
def displayForState(s):
  d = str(s[0] + s[1] + s[2] + '\n' \
          + s[3] + s[4] + s[5] + '\n' \
          + s[6] + s[7] + s[8])
  d = d.replace(' ', '.')
  return d

def displayValues(env):
  for s in env.valueTable.keys():
    player1value = env.valueTable[s][0]
    player2value = env.valueTable[s][1]

    player1policy, player2policy = -1, -1
    if (s in env.policyTable):
      player1policy= env.policyTable[s][0]
      player2policy= env.policyTable[s][1]

    #function to reduce bloat
    if player1value != 0 and player2value != 0 and player1policy != -1:
      print("\n")
      print(displayForState(s))
      print("player 1 value: ", player1value, "policy: ", player1policy)
      print("player 2 value: ", player2value, "policy: ", player2policy)

# %% [markdown]
# #Policy Iteration

# %%
#policy iteration
experiment(env, 100, 10, False)
# Out:
# Episode: 0
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#    |   | O
# ___|___|___
#    |   |
#  X |   | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 1
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#    | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 2
#    |   |
#    |   | X
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 3
#    |   |
#    | O | O
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 4
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | O |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 5
#    |   |
#  X |   |
# ___|___|___
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 6
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#  O | X |
# ___|___|___
#    |   |
#    | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 7
#    |   |
#  O |   |
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 8
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 9
#    |   |
#    | O |
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 10
#    |   |
#    | X |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 11
#    |   |
#  O |   | X
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 12
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 13
#    |   |
#    |   | O
# ___|___|___
#    |   |
#  X | X | O
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 14
#    |   |
#  O |   | X
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 15
#    |   |
#  X | O |
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 16
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 17
#    |   |
#    | X |
# ___|___|___
#    |   |
#    | X | O
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 18
#    |   |
#    |   | O
# ___|___|___
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 19
#    |   |
#  X |   |
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X |   | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 20
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 21
#    |   |
#  O | X |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 22
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#  X |   | X
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 23
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 24
#    |   |
#    |   | O
# ___|___|___
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 25
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 26
#    |   |
#  X | X |
# ___|___|___
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 27
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 28
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  O |   | X
# ___|___|___
#    |   |
#    |   | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 29
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 30
#    |   |
#  X |   |
# ___|___|___
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  O |   | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 31
#    |   |
#    | O |
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 32
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 33
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#  X |   | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 34
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#    |   | O
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 35
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O |   |
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 36
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#    | O | O
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 37
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 38
#    |   |
#    | X | O
# ___|___|___
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 39
#    |   |
#    |   | O
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 40
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#    | O | O
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 41
#    |   |
#    | O |
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 42
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#  O | X |
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 43
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 44
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 45
#    |   |
#  O |   | X
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 46
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 47
#    |   |
#  O |   |
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 48
#    |   |
#  O |   |
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 49
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#    | O | O
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 50
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 51
#    |   |
#  O | X |
# ___|___|___
#    |   |
#    | X | O
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 52
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 53
#    |   |
#  O |   | X
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 54
#    |   |
#  O |   | X
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 55
#    |   |
#  O |   | O
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 56
#    |   |
#    |   | O
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 57
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 58
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 59
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  O |   | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 60
#    |   |
#    | O | X
# ___|___|___
#    |   |
#    |   | X
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 61
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# draw
#
# rewards: 1.0 1.0
#
# Episode: 62
#    |   |
#  O |   | O
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 63
#    |   |
#  O | X |
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 64
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#    | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 65
#    |   |
#    |   | X
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 66
#    |   |
#  O |   | O
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 67
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# draw
#
# rewards: 1.0 1.0
#
# Episode: 68
#    |   |
#    |   | O
# ___|___|___
#    |   |
#    | X | O
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 69
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 70
#    |   |
#  X |   |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 71
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# draw
#
# rewards: 1.0 1.0
#
# Episode: 72
#    |   |
#  O |   | O
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 73
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 74
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 75
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#    |   | O
# ___|___|___
#    |   |
#  X |   | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 76
#    |   |
#  X |   |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | O | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 77
#    |   |
#  O |   | O
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 78
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 79
#    |   |
#  X |   |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 80
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 81
#    |   |
#    |   | O
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 82
#    |   |
#  X |   |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 83
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 84
#    |   |
#    | O |
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 85
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 86
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 87
#    |   |
#  X |   |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 88
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 89
#    |   |
#  X |   |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 90
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 91
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 92
#    |   |
#  O |   | O
# ___|___|___
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 93
#    |   |
#  X | O |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 94
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#  X |   | X
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 95
#    |   |
#  X |   |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 96
#    |   |
#  X | X | O
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 97
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 98
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 99
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Player1:  48 Player2: 49 Wins: 97  Draws: 3
# Player1 Rewards:  1.0  Player2 Rewards: 5.0
# Player1 Average:  0.1  Player2 Average: 0.5

# %%
#policy iteration
displayValues(env)
# Out:
# X.O
# ...
# ...
# player 1 value:  16.0 policy:  6
# player 2 value:  8.0 policy:  8
#
#
# ..O
# ...
# ..X
# player 1 value:  8.0 policy:  0
# player 2 value:  8.0 policy:  6
#
#
# X.O
# ...
# ..O
# player 1 value:  24.0 policy:  6
# player 2 value:  4.0 policy:  5
#
#
# X.O
# ...
# X..
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  8
#
#
# X.O
# ...
# ..X
# player 1 value:  4.0 policy:  4
# player 2 value:  32.0 policy:  7
#
#
# X.O
# ...
# X.O
# player 1 value:  12.0 policy:  5
# player 2 value:  4.0 policy:  5
#
#
# ...
# O..
# ..X
# player 1 value:  8.0 policy:  6
# player 2 value:  8.0 policy:  0
#
#
# ...
# .O.
# ..X
# player 1 value:  8.0 policy:  7
# player 2 value:  8.0 policy:  7
#
#
# ...
# ...
# .OX
# player 1 value:  16.0 policy:  4
# player 2 value:  16.0 policy:  1
#
#
# .X.
# .OO
# ..X
# player 1 value:  8.0 policy:  7
# player 2 value:  4.0 policy:  3
#
#
# .X.
# .OO
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  4.0 policy:  3
#
#
# ...
# .O.
# .OX
# player 1 value:  56.0 policy:  6
# player 2 value:  4.0 policy:  1
#
#
# ...
# .O.
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  8.0 policy:  6
#
#
# ...
# .OX
# .OX
# player 1 value:  12.0 policy:  6
# player 2 value:  36.0 policy:  2
#
#
# ...
# .O.
# XOX
# player 1 value:  16.0 policy:  0
# player 2 value:  19.999987602233887 policy:  5
#
#
# ...
# .OX
# OOX
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  1
#
#
# ...
# .OX
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  28.0 policy:  0
#
#
# .O.
# ...
# .OX
# player 1 value:  40.0 policy:  6
# player 2 value:  4.0 policy:  4
#
#
# ...
# ..X
# .OX
# player 1 value:  4.0 policy:  2
# player 2 value:  72.0 policy:  4
#
#
# X.X
# .O.
# .XO
# player 1 value:  4.0 policy:  1
# player 2 value:  8.0 policy:  3
#
#
# X.X
# OO.
# .XO
# player 1 value:  4.0 policy:  1
# player 2 value:  4.0 policy:  5
#
#
# X..
# ...
# ..O
# player 1 value:  8.0 policy:  6
# player 2 value:  16.0 policy:  2
#
#
# .X.
# ...
# ..O
# player 1 value:  8.0 policy:  7
# player 2 value:  8.0 policy:  0
#
#
# ...
# .X.
# ..O
# player 1 value:  8.0 policy:  7
# player 2 value:  8.0 policy:  7
#
#
# ...
# ...
# .XO
# player 1 value:  16.0 policy:  1
# player 2 value:  8.0 policy:  4
#
#
# ...
# X..
# .OO
# player 1 value:  16.0 policy:  4
# player 2 value:  4.0 policy:  6
#
#
# ...
# XX.
# .OO
# player 1 value:  4.0 policy:  5
# player 2 value:  20.0 policy:  5
#
#
# ...
# X..
# XOO
# player 1 value:  4.0 policy:  0
# player 2 value:  8.0 policy:  5
#
#
# ...
# X.O
# XOO
# player 1 value:  20.0 policy:  4
# player 2 value:  4.0 policy:  2
#
#
# ...
# XXO
# XOO
# player 1 value:  8.0 policy:  0
# player 2 value:  4.0 policy:  2
#
#
# OX.
# ...
# ...
# player 1 value:  8.0 policy:  7
# player 2 value:  8.0 policy:  8
#
#
# O..
# O..
# ..X
# player 1 value:  16.0 policy:  2
# player 2 value:  4.0 policy:  6
#
#
# O.X
# O..
# ..X
# player 1 value:  4.0 policy:  5
# player 2 value:  12.0 policy:  1
#
#
# O..
# O..
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  20.0 policy:  1
#
#
# OO.
# O..
# .XX
# player 1 value:  12.0 policy:  4
# player 2 value:  8.0 policy:  2
#
#
# OO.
# OX.
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  8.0 policy:  2
#
#
# ...
# .O.
# OXX
# player 1 value:  8.0 policy:  5
# player 2 value:  4.0 policy:  2
#
#
# OX.
# .O.
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  16.0 policy:  6
#
#
# .O.
# ..X
# O.X
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  7
#
#
# XO.
# ..O
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  16.0 policy:  4
#
#
# XO.
# .OO
# OXX
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  2
#
#
# XO.
# XOO
# OXX
# player 1 value:  2.0 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# .O.
# ...
# XOX
# player 1 value:  16.0 policy:  3
# player 2 value:  4.0 policy:  4
#
#
# .O.
# X..
# XOX
# player 1 value:  4.0 policy:  0
# player 2 value:  20.0 policy:  0
#
#
# .O.
# ..X
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  12.0 policy:  3
#
#
# ...
# .X.
# .XO
# player 1 value:  4.0 policy:  1
# player 2 value:  16.0 policy:  6
#
#
# ...
# .X.
# .OO
# player 1 value:  16.0 policy:  3
# player 2 value:  4.0 policy:  6
#
#
# ...
# .X.
# OXO
# player 1 value:  20.0 policy:  5
# player 2 value:  8.0 policy:  5
#
#
# ...
# .XX
# OXO
# player 1 value:  8.0 policy:  1
# player 2 value:  8.0 policy:  3
#
#
# ...
# .XO
# OXO
# player 1 value:  12.0 policy:  0
# player 2 value:  4.0 policy:  2
#
#
# X.O
# ...
# .OX
# player 1 value:  4.0 policy:  4
# player 2 value:  16.0 policy:  4
#
#
# X.O
# .O.
# .OX
# player 1 value:  8.0 policy:  6
# player 2 value:  8.0 policy:  1
#
#
# ...
# XXO
# .OO
# player 1 value:  16.0 policy:  6
# player 2 value:  8.0 policy:  2
#
#
# O..
# ..X
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  4
#
#
# O..
# .OX
# XOX
# player 1 value:  12.0 policy:  1
# player 2 value:  4.0 policy:  1
#
#
# OX.
# .OX
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  2
#
#
# X..
# .O.
# XOX
# player 1 value:  4.0 policy:  3
# player 2 value:  12.0 policy:  2
#
#
# X.O
# .O.
# XOX
# player 1 value:  4.0 policy:  3
# player 2 value:  4.0 policy:  1
#
#
# OX.
# ...
# ..O
# player 1 value:  24.0 policy:  7
# player 2 value:  4.0 policy:  4
#
#
# .X.
# ...
# .XO
# player 1 value:  4.0 policy:  4
# player 2 value:  64.0 policy:  0
#
#
# OX.
# ...
# .XO
# player 1 value:  12.0 policy:  3
# player 2 value:  20.0 policy:  3
#
#
# OX.
# O..
# .XO
# player 1 value:  12.0 policy:  5
# player 2 value:  8.0 policy:  4
#
#
# OX.
# X..
# .XO
# player 1 value:  4.0 policy:  4
# player 2 value:  20.0 policy:  2
#
#
# OX.
# O.X
# .XO
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  4
#
#
# .X.
# ...
# OXO
# player 1 value:  20.0 policy:  2
# player 2 value:  8.0 policy:  5
#
#
# ...
# ..X
# OXO
# player 1 value:  16.0 policy:  4
# player 2 value:  16.0 policy:  4
#
#
# X..
# .XO
# OXO
# player 1 value:  4.0 policy:  1
# player 2 value:  12.0 policy:  3
#
#
# O.O
# X..
# .XO
# player 1 value:  24.0 policy:  1
# player 2 value:  12.0 policy:  1
#
#
# ..O
# XO.
# .XO
# player 1 value:  8.0 policy:  6
# player 2 value:  12.0 policy:  0
#
#
# ..O
# X..
# OXO
# player 1 value:  8.0 policy:  5
# player 2 value:  8.0 policy:  4
#
#
# ..O
# X.X
# OXO
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# X..
# ...
# X.O
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  2
#
#
# ...
# ..X
# O.O
# player 1 value:  32.0 policy:  7
# player 2 value:  4.0 policy:  7
#
#
# X..
# ..X
# .OO
# player 1 value:  8.0 policy:  6
# player 2 value:  4.0 policy:  6
#
#
# X..
# ..X
# XOO
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  4
#
#
# X..
# .OX
# XOO
# player 1 value:  20.0 policy:  1
# player 2 value:  4.0 policy:  1
#
#
# X.X
# O.X
# XOO
# player 1 value:  8.0 policy:  1
# player 2 value:  8.0 policy:  4
#
#
# X.X
# OOX
# XOO
# player 1 value:  4.0 policy:  1
# player 2 value:  4.0 policy:  1
#
#
# ...
# .OX
# OXO
# player 1 value:  16.0 policy:  2
# player 2 value:  8.0 policy:  0
#
#
# ..X
# .OX
# OXO
# player 1 value:  8.0 policy:  1
# player 2 value:  4.0 policy:  0
#
#
# XX.
# .OX
# XOO
# player 1 value:  8.0 policy:  2
# player 2 value:  4.0 policy:  3
#
#
# XX.
# OOX
# XOO
# player 1 value:  4.0 policy:  2
# player 2 value:  2.0 policy:  2
#
#
# X..
# OXO
# OXO
# player 1 value:  4.0 policy:  1
# player 2 value:  4.0 policy:  2
#
#
# .XX
# .OX
# OXO
# player 1 value:  4.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# OOX
# O..
# ..X
# player 1 value:  4.0 policy:  5
# player 2 value:  4.0 policy:  6
#
#
# ...
# .O.
# .XO
# player 1 value:  32.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# OXO
# X..
# .XO
# player 1 value:  12.0 policy:  6
# player 2 value:  8.0 policy:  4
#
#
# OXO
# X..
# XXO
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  4
#
#
# X..
# ..O
# O.X
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  3
#
#
# X..
# O.O
# O.X
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# .O.
# O.X
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  4
#
#
# OX.
# ...
# .X.
# player 1 value:  4.0 policy:  4
# player 2 value:  40.0 policy:  8
#
#
# OO.
# X..
# XOX
# player 1 value:  16.0 policy:  5
# player 2 value:  8.0 policy:  2
#
#
# OO.
# X.X
# XOX
# player 1 value:  8.0 policy:  2
# player 2 value:  8.0 policy:  2
#
#
# .XX
# ...
# OXO
# player 1 value:  8.0 policy:  0
# player 2 value:  32.0 policy:  5
#
#
# .X.
# ..O
# OXO
# player 1 value:  28.0 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# .XX
# ..O
# OXO
# player 1 value:  8.0 policy:  0
# player 2 value:  16.0 policy:  4
#
#
# .XX
# .OO
# OXO
# player 1 value:  12.0 policy:  3
# player 2 value:  8.0 policy:  0
#
#
# .X.
# X.O
# OXO
# player 1 value:  4.0 policy:  4
# player 2 value:  20.0 policy:  4
#
#
# .XX
# XOO
# OXO
# player 1 value:  4.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# OX.
# .XO
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  3
#
#
# OX.
# OXO
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  2.0 policy:  2
#
#
# .XO
# O..
# .XX
# player 1 value:  8.0 policy:  4
# player 2 value:  16.0 policy:  6
#
#
# .XO
# O..
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  0
#
#
# .X.
# XOO
# OXO
# player 1 value:  8.0 policy:  2
# player 2 value:  8.0 policy:  0
#
#
# X..
# .O.
# .XO
# player 1 value:  8.0 policy:  2
# player 2 value:  8.0 policy:  6
#
#
# ..X
# .O.
# .XO
# player 1 value:  8.0 policy:  0
# player 2 value:  12.0 policy:  1
#
#
# .O.
# XO.
# .XO
# player 1 value:  8.0 policy:  6
# player 2 value:  4.0 policy:  0
#
#
# .O.
# XO.
# XXO
# player 1 value:  4.0 policy:  0
# player 2 value:  20.0 policy:  2
#
#
# .OO
# XO.
# XXO
# player 1 value:  12.0 policy:  5
# player 2 value:  8.0 policy:  0
#
#
# .OO
# XOX
# XXO
# player 1 value:  4.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# OX.
# .O.
# OXX
# player 1 value:  8.0 policy:  5
# player 2 value:  8.0 policy:  2
#
#
# OX.
# .OX
# OXX
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  2
#
#
# .O.
# .O.
# XXO
# player 1 value:  16.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# ..O
# .O.
# XXO
# player 1 value:  8.0 policy:  3
# player 2 value:  8.0 policy:  0
#
#
# OXX
# ..O
# ..O
# player 1 value:  8.0 policy:  7
# player 2 value:  4.0 policy:  4
#
#
# OXX
# ..O
# .XO
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# XO.
# .O.
# XXO
# player 1 value:  4.0 policy:  3
# player 2 value:  16.0 policy:  5
#
#
# .X.
# ..O
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  0
#
#
# OX.
# ..O
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  3
#
#
# ...
# OOX
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  1
#
#
# ..O
# XO.
# XXO
# player 1 value:  4.0 policy:  0
# player 2 value:  24.0 policy:  1
#
#
# ...
# OXX
# OXO
# player 1 value:  4.0 policy:  1
# player 2 value:  4.0 policy:  0
#
#
# OXO
# .OX
# XOX
# player 1 value:  2.0 policy:  3
# player 2 value:  2.0 policy:  3
#
#
# OX.
# OOX
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  2.0 policy:  2
#
#
# ...
# O.X
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  16.0 policy:  1
#
#
# .O.
# ..X
# OOX
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  4
#
#
# .O.
# .XX
# ..O
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  7
#
#
# .O.
# .XX
# .OO
# player 1 value:  4.0 policy:  3
# player 2 value:  4.0 policy:  6
#
#
# ..O
# .X.
# X.O
# player 1 value:  8.0 policy:  7
# player 2 value:  4.0 policy:  5
#
#
# ..O
# .X.
# XXO
# player 1 value:  4.0 policy:  1
# player 2 value:  4.0 policy:  5
#
#
# XO.
# .OO
# XXO
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  2
#
#
# .OX
# .OO
# XXO
# player 1 value:  8.0 policy:  3
# player 2 value:  8.0 policy:  0
#
#
# ...
# .OX
# OXX
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# OX.
# ...
# O.X
# player 1 value:  8.0 policy:  7
# player 2 value:  4.0 policy:  3
#
#
# OX.
# ...
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  44.0 policy:  2
#
#
# OXO
# ...
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  3
#
#
# .OX
# XOO
# XXO
# player 1 value:  4.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# ..O
# O.X
# OXX
# player 1 value:  16.0 policy:  4
# player 2 value:  8.0 policy:  0
#
#
# ..O
# OXX
# OXX
# player 1 value:  8.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# X..
# .O.
# OXO
# player 1 value:  7.9999999999972715 policy:  1
# player 2 value:  4.0 policy:  2
#
#
# XX.
# .O.
# OXO
# player 1 value:  3.9999999999999716 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# .OX
# XO.
# OXO
# player 1 value:  3.9999969005584717 policy:  5
# player 2 value:  3.9999999999999982 policy:  0
#
#
# .OX
# XOX
# OXO
# player 1 value:  1.9999999403953552 policy:  0
# player 2 value:  3.9999999999999982 policy:  0

# %% [markdown]
# #Value Iteration

# %%
#value iteration
experiment(env, 100, 10, True)
# Out:
# Episode: 0
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X |   | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 1
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# draw
#
# rewards: 1.0 1.0
#
# Episode: 2
#    |   |
#  X |   |
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 3
#    |   |
#    | O |
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 4
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 5
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  X | X | O
# ___|___|___
#    |   |
#  O | O | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 6
#    |   |
#  O |   |
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 7
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 8
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X | X | O
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 9
#    |   |
#    | X | O
# ___|___|___
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 10
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#    |   |
# ___|___|___
#    |   |
#  X |   | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 11
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 12
#    |   |
#  O |   |
# ___|___|___
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 13
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# draw
#
# rewards: 1.0 1.0
#
# Episode: 14
#    |   |
#    | O |
# ___|___|___
#    |   |
#    |   | O
# ___|___|___
#    |   |
#  X | X | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 15
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 16
#    |   |
#  O |   | O
# ___|___|___
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 17
#    |   |
#  X |   |
# ___|___|___
#    |   |
#    | X | O
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 18
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#    | X | X
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 19
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  X | X | O
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 20
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 21
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 22
#    |   |
#  X |   |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 23
#    |   |
#  X | X | O
# ___|___|___
#    |   |
#    |   | O
# ___|___|___
#    |   |
#    |   | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 24
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 25
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#    | O |
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 26
#    |   |
#  X |   | X
# ___|___|___
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 27
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O |   |
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 28
#    |   |
#  O |   | X
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 29
#    |   |
#    |   | X
# ___|___|___
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 30
#    |   |
#  X |   |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 31
#    |   |
#    |   | O
# ___|___|___
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 32
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  O | X |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 33
#    |   |
#  X |   |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 34
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#    | X | O
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 35
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#    |   | O
# ___|___|___
#    |   |
#  X |   | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 36
#    |   |
#    | X | X
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 37
#    |   |
#  O |   |
# ___|___|___
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 38
#    |   |
#    |   | O
# ___|___|___
#    |   |
#  X | O | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 39
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 40
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 41
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 42
#    |   |
#    | X | O
# ___|___|___
#    |   |
#  X | O | O
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 43
#    |   |
#    |   | O
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 44
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#  X |   | X
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 45
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | O |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 46
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#    |   | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 47
#    |   |
#    |   | X
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 48
#    |   |
#  X | O |
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 49
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O |   |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 50
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 51
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 52
#    |   |
#  O | O |
# ___|___|___
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 53
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 54
#    |   |
#    |   |
# ___|___|___
#    |   |
#  O | O |
# ___|___|___
#    |   |
#  X | X | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 55
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 56
#    |   |
#    |   | O
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 57
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 58
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 59
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#    | X | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 60
#    |   |
#  X | X |
# ___|___|___
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 61
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X | X | O
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 62
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 63
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | O | X
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 64
#    |   |
#  X |   | X
# ___|___|___
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 65
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 66
#    |   |
#    |   |
# ___|___|___
#    |   |
#  O | O |
# ___|___|___
#    |   |
#  X | X | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 67
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 68
#    |   |
#    |   | X
# ___|___|___
#    |   |
#    | X | O
# ___|___|___
#    |   |
#  X |   | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 69
#    |   |
#  X | O |
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 70
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 71
#    |   |
#  O |   |
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 72
#    |   |
#  X |   | X
# ___|___|___
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 73
#    |   |
#    |   | O
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 74
#    |   |
#  O | X | X
# ___|___|___
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 75
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 76
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O |   |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 77
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O |   |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 78
#    |   |
#    | X | O
# ___|___|___
#    |   |
#    | X | O
# ___|___|___
#    |   |
#  O | X | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 79
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O |   |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 80
#    |   |
#  X |   | X
# ___|___|___
#    |   |
#  O | O | O
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 81
#    |   |
#  X | X | O
# ___|___|___
#    |   |
#    | X | O
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 82
#    |   |
#  O | O |
# ___|___|___
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 83
#    |   |
#  X |   | X
# ___|___|___
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 84
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | X |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 85
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#  X | O |
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 86
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#    | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 87
#    |   |
#  X |   | X
# ___|___|___
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  O | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 88
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | O |
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 89
#    |   |
#  O |   | X
# ___|___|___
#    |   |
#    |   | X
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 90
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | O |
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 91
#    |   |
#  O | X | O
# ___|___|___
#    |   |
#    | O |
# ___|___|___
#    |   |
#  X | X | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 92
#    |   |
#    |   | X
# ___|___|___
#    |   |
#  O |   | X
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 93
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | O |
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 94
#    |   |
#  O | O |
# ___|___|___
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 95
#    |   |
#  O |   | X
# ___|___|___
#    |   |
#  O | X |
# ___|___|___
#    |   |
#  X | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 96
#    |   |
#  X | O |
# ___|___|___
#    |   |
#    | O | X
# ___|___|___
#    |   |
#  X | O | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 97
#    |   |
#  X | X | X
# ___|___|___
#    |   |
#  O | O |
# ___|___|___
#    |   |
#    | O | X
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Episode: 98
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#  X |   | O
# ___|___|___
#    |   |
#    |   | O
#    |   |
#
# winner: player 2
#
# rewards: -2.0 2.0
#
# Episode: 99
#    |   |
#  O | X |
# ___|___|___
#    |   |
#    | X |
# ___|___|___
#    |   |
#  O | X | O
#    |   |
#
# winner: player 1
#
# rewards: 2.0 -2.0
#
# Player1:  55 Player2: 43 Wins: 98  Draws: 2
# Player1 Rewards:  26.0  Player2 Rewards: -22.0
# Player1 Average:  2.6  Player2 Average: -2.2

# %%
#value iteration
displayValues(env)
# Out:
# X.O
# ...
# ...
# player 1 value:  16.0 policy:  6
# player 2 value:  8.0 policy:  8
#
#
# ..O
# ...
# X..
# player 1 value:  8.0 policy:  0
# player 2 value:  8.0 policy:  1
#
#
# ..O
# ...
# ..X
# player 1 value:  8.0 policy:  0
# player 2 value:  8.0 policy:  6
#
#
# X.O
# ...
# ..O
# player 1 value:  32.0 policy:  6
# player 2 value:  4.0 policy:  5
#
#
# X.O
# ...
# X..
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  8
#
#
# X.O
# ...
# ..X
# player 1 value:  4.0 policy:  4
# player 2 value:  32.0 policy:  7
#
#
# X.O
# X..
# ..O
# player 1 value:  4.0 policy:  6
# player 2 value:  4.0 policy:  5
#
#
# X.O
# ...
# X.O
# player 1 value:  12.0 policy:  5
# player 2 value:  4.0 policy:  5
#
#
# .O.
# ...
# ..X
# player 1 value:  8.0 policy:  7
# player 2 value:  8.0 policy:  7
#
#
# ...
# O..
# ..X
# player 1 value:  8.0 policy:  6
# player 2 value:  8.0 policy:  0
#
#
# ...
# .O.
# ..X
# player 1 value:  8.0 policy:  7
# player 2 value:  8.0 policy:  7
#
#
# ...
# ...
# .OX
# player 1 value:  24.0 policy:  2
# player 2 value:  16.0 policy:  1
#
#
# ...
# ..O
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  8.0 policy:  4
#
#
# .X.
# .OO
# ..X
# player 1 value:  8.0 policy:  7
# player 2 value:  4.0 policy:  3
#
#
# .X.
# .OO
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  20.0 policy:  6
#
#
# .X.
# .OO
# OXX
# player 1 value:  8.0 policy:  0
# player 2 value:  8.0 policy:  2
#
#
# ..X
# .O.
# ...
# player 1 value:  8.0 policy:  0
# player 2 value:  8.0 policy:  1
#
#
# ...
# .O.
# .OX
# player 1 value:  72.0 policy:  6
# player 2 value:  4.0 policy:  1
#
#
# ...
# .O.
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  24.0 policy:  2
#
#
# X..
# .O.
# .OX
# player 1 value:  8.0 policy:  6
# player 2 value:  20.0 policy:  2
#
#
# ...
# .OX
# .OX
# player 1 value:  12.0 policy:  6
# player 2 value:  36.0 policy:  2
#
#
# ...
# .O.
# XOX
# player 1 value:  16.0 policy:  0
# player 2 value:  20.0 policy:  5
#
#
# ...
# .OX
# OOX
# player 1 value:  20.0 policy:  1
# player 2 value:  8.0 policy:  1
#
#
# ...
# .OX
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  28.0 policy:  0
#
#
# .X.
# .OX
# OOX
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# ...
# XOX
# OOX
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  1
#
#
# .O.
# ...
# .OX
# player 1 value:  80.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# ..X
# ...
# .OX
# player 1 value:  4.0 policy:  5
# player 2 value:  32.0 policy:  3
#
#
# ...
# ..X
# .OX
# player 1 value:  4.0 policy:  2
# player 2 value:  72.0 policy:  4
#
#
# X.X
# .O.
# ...
# player 1 value:  4.0 policy:  1
# player 2 value:  8.0 policy:  1
#
#
# X.X
# .O.
# .XO
# player 1 value:  4.0 policy:  1
# player 2 value:  32.0 policy:  3
#
#
# X.X
# OO.
# .XO
# player 1 value:  4.0 policy:  1
# player 2 value:  12.0 policy:  1
#
#
# X.X
# .OO
# .XO
# player 1 value:  4.0 policy:  1
# player 2 value:  4.0 policy:  3
#
#
# XOX
# OO.
# .XO
# player 1 value:  4.0 policy:  6
# player 2 value:  4.0 policy:  5
#
#
# X..
# ...
# ..O
# player 1 value:  8.0 policy:  6
# player 2 value:  16.0 policy:  2
#
#
# .X.
# ...
# ..O
# player 1 value:  8.0 policy:  7
# player 2 value:  8.0 policy:  0
#
#
# ...
# .X.
# ..O
# player 1 value:  8.0 policy:  7
# player 2 value:  8.0 policy:  7
#
#
# ...
# ...
# X.O
# player 1 value:  8.0 policy:  0
# player 2 value:  8.0 policy:  4
#
#
# ...
# ...
# .XO
# player 1 value:  16.0 policy:  1
# player 2 value:  16.0 policy:  0
#
#
# ..O
# X..
# ..O
# player 1 value:  8.0 policy:  0
# player 2 value:  4.0 policy:  5
#
#
# ...
# X..
# .OO
# player 1 value:  16.0 policy:  4
# player 2 value:  4.0 policy:  6
#
#
# ...
# XX.
# .OO
# player 1 value:  4.0 policy:  5
# player 2 value:  20.0 policy:  5
#
#
# ...
# X..
# XOO
# player 1 value:  4.0 policy:  0
# player 2 value:  24.0 policy:  4
#
#
# ...
# XO.
# XOO
# player 1 value:  4.0 policy:  0
# player 2 value:  8.0 policy:  0
#
#
# ...
# X.O
# XOO
# player 1 value:  20.0 policy:  4
# player 2 value:  4.0 policy:  2
#
#
# ...
# XXO
# XOO
# player 1 value:  8.0 policy:  0
# player 2 value:  4.0 policy:  2
#
#
# OX.
# ...
# ...
# player 1 value:  8.0 policy:  7
# player 2 value:  8.0 policy:  8
#
#
# O..
# O..
# ..X
# player 1 value:  55.63330078125 policy:  6
# player 2 value:  4.0 policy:  6
#
#
# O.X
# O..
# ..X
# player 1 value:  4.0 policy:  5
# player 2 value:  12.0 policy:  1
#
#
# O..
# O..
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  20.0 policy:  1
#
#
# OO.
# O..
# .XX
# player 1 value:  12.0 policy:  4
# player 2 value:  8.0 policy:  2
#
#
# OO.
# OX.
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  8.0 policy:  2
#
#
# ..O
# .O.
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  4.0 policy:  6
#
#
# ...
# .OO
# .XX
# player 1 value:  12.0 policy:  1
# player 2 value:  4.0 policy:  3
#
#
# ...
# .O.
# OXX
# player 1 value:  8.0 policy:  5
# player 2 value:  4.0 policy:  2
#
#
# OX.
# .O.
# .XX
# player 1 value:  4.0 policy:  6
# player 2 value:  16.0 policy:  6
#
#
# .O.
# ..X
# O.X
# player 1 value:  12.0 policy:  7
# player 2 value:  8.0 policy:  7
#
#
# .O.
# ..X
# OXX
# player 1 value:  4.0 policy:  2
# player 2 value:  16.0 policy:  0
#
#
# XO.
# ..O
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  16.0 policy:  4
#
#
# XO.
# .OO
# OXX
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  2
#
#
# XO.
# XOO
# OXX
# player 1 value:  2.0 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# XO.
# ...
# .OX
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# .O.
# ...
# XOX
# player 1 value:  16.0 policy:  3
# player 2 value:  4.0 policy:  4
#
#
# .O.
# X..
# XOX
# player 1 value:  4.0 policy:  0
# player 2 value:  20.0 policy:  0
#
#
# .O.
# ..X
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  12.0 policy:  3
#
#
# ...
# .X.
# .XO
# player 1 value:  4.0 policy:  1
# player 2 value:  47.96240234375 policy:  6
#
#
# ...
# .X.
# .OO
# player 1 value:  16.0 policy:  3
# player 2 value:  4.0 policy:  6
#
#
# O..
# .X.
# .XO
# player 1 value:  3.9999847412109375 policy:  1
# player 2 value:  7.9989013671875 policy:  6
#
#
# ...
# .X.
# OXO
# player 1 value:  20.0 policy:  5
# player 2 value:  15.9989013671875 policy:  5
#
#
# ...
# .XX
# OXO
# player 1 value:  8.0 policy:  1
# player 2 value:  112.0 policy:  0
#
#
# O..
# .X.
# OXO
# player 1 value:  19.999923706054688 policy:  5
# player 2 value:  3.999969482421875 policy:  3
#
#
# ...
# .XO
# OXO
# player 1 value:  12.0 policy:  0
# player 2 value:  4.0 policy:  2
#
#
# X.O
# ...
# .OX
# player 1 value:  4.0 policy:  4
# player 2 value:  16.0 policy:  4
#
#
# X.O
# .O.
# .OX
# player 1 value:  8.0 policy:  6
# player 2 value:  8.0 policy:  1
#
#
# ...
# XXO
# .OO
# player 1 value:  16.0 policy:  6
# player 2 value:  8.0 policy:  2
#
#
# O..
# ..X
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  4
#
#
# O..
# .OX
# XOX
# player 1 value:  12.0 policy:  1
# player 2 value:  4.0 policy:  1
#
#
# OX.
# .OX
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  2
#
#
# X..
# .O.
# XOX
# player 1 value:  4.0 policy:  3
# player 2 value:  12.0 policy:  2
#
#
# ...
# .OO
# XOX
# player 1 value:  8.0 policy:  3
# player 2 value:  8.0 policy:  1
#
#
# X.O
# .O.
# XOX
# player 1 value:  4.0 policy:  3
# player 2 value:  4.0 policy:  1
#
#
# OX.
# ...
# ..O
# player 1 value:  24.0 policy:  7
# player 2 value:  4.0 policy:  4
#
#
# .X.
# ...
# .XO
# player 1 value:  4.0 policy:  4
# player 2 value:  96.0 policy:  0
#
#
# OX.
# ...
# .XO
# player 1 value:  12.0 policy:  3
# player 2 value:  36.0 policy:  2
#
#
# OXO
# ...
# .XO
# player 1 value:  60.0 policy:  3
# player 2 value:  8.0 policy:  4
#
#
# OX.
# O..
# .XO
# player 1 value:  20.0 policy:  2
# player 2 value:  8.0 policy:  4
#
#
# OX.
# X..
# .XO
# player 1 value:  4.0 policy:  4
# player 2 value:  36.0 policy:  2
#
#
# OXX
# O..
# .XO
# player 1 value:  4.0 policy:  4
# player 2 value:  24.0 policy:  5
#
#
# OX.
# O.X
# .XO
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  4
#
#
# .X.
# ...
# OXO
# player 1 value:  20.0 policy:  2
# player 2 value:  8.0 policy:  5
#
#
# ...
# ..X
# OXO
# player 1 value:  16.0 policy:  4
# player 2 value:  32.0 policy:  0
#
#
# X..
# .XO
# OXO
# player 1 value:  4.0 policy:  1
# player 2 value:  12.0 policy:  3
#
#
# O.O
# X..
# .XO
# player 1 value:  24.0 policy:  1
# player 2 value:  12.0 policy:  1
#
#
# ..O
# XO.
# .XO
# player 1 value:  8.0 policy:  6
# player 2 value:  12.0 policy:  0
#
#
# ..O
# X..
# OXO
# player 1 value:  8.0 policy:  5
# player 2 value:  8.0 policy:  4
#
#
# ..O
# X.X
# OXO
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# X..
# ...
# X.O
# player 1 value:  4.0 policy:  3
# player 2 value:  54.25 policy:  7
#
#
# ...
# .O.
# X.O
# player 1 value:  16.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# X..
# .O.
# X.O
# player 1 value:  4.0 policy:  3
# player 2 value:  7.9140625 policy:  7
#
#
# X..
# ...
# XOO
# player 1 value:  12.0 policy:  5
# player 2 value:  15.9140625 policy:  5
#
#
# X..
# .O.
# XOO
# player 1 value:  43.95703125 policy:  5
# player 2 value:  3.99609375 policy:  1
#
#
# ...
# ..X
# O.O
# player 1 value:  32.0 policy:  7
# player 2 value:  4.0 policy:  7
#
#
# ...
# ..X
# .OO
# player 1 value:  16.0 policy:  0
# player 2 value:  4.0 policy:  6
#
#
# X..
# ..X
# .OO
# player 1 value:  8.0 policy:  6
# player 2 value:  20.0 policy:  4
#
#
# X..
# ..X
# XOO
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  4
#
#
# X..
# .OX
# .OO
# player 1 value:  40.0 policy:  6
# player 2 value:  8.0 policy:  1
#
#
# X..
# .OX
# XOO
# player 1 value:  20.0 policy:  1
# player 2 value:  4.0 policy:  1
#
#
# X.X
# O.X
# XOO
# player 1 value:  8.0 policy:  1
# player 2 value:  8.0 policy:  4
#
#
# X.X
# OOX
# XOO
# player 1 value:  4.0 policy:  1
# player 2 value:  4.0 policy:  1
#
#
# O..
# ..X
# OXO
# player 1 value:  16.0 policy:  4
# player 2 value:  8.0 policy:  3
#
#
# ...
# .OX
# OXO
# player 1 value:  16.0 policy:  2
# player 2 value:  8.0 policy:  0
#
#
# ..X
# .OX
# OXO
# player 1 value:  8.0 policy:  1
# player 2 value:  4.0 policy:  0
#
#
# .O.
# XOX
# OXO
# player 1 value:  8.0 policy:  0
# player 2 value:  8.0 policy:  0
#
#
# X..
# ..O
# XOO
# player 1 value:  20.0 policy:  4
# player 2 value:  4.0 policy:  2
#
#
# XX.
# .OX
# XOO
# player 1 value:  8.0 policy:  2
# player 2 value:  4.0 policy:  3
#
#
# XX.
# OOX
# XOO
# player 1 value:  4.0 policy:  2
# player 2 value:  2.0 policy:  2
#
#
# X..
# OXO
# OXO
# player 1 value:  4.0 policy:  1
# player 2 value:  4.0 policy:  2
#
#
# .XX
# .OX
# OXO
# player 1 value:  4.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# OOX
# O..
# ..X
# player 1 value:  4.0 policy:  5
# player 2 value:  4.0 policy:  6
#
#
# O..
# ...
# .XO
# player 1 value:  47.999420166015625 policy:  1
# player 2 value:  4.0 policy:  4
#
#
# ...
# .O.
# .XO
# player 1 value:  32.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# OXO
# X..
# .XO
# player 1 value:  12.0 policy:  6
# player 2 value:  8.0 policy:  4
#
#
# OX.
# X.O
# .XO
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  2
#
#
# OXO
# X..
# XXO
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  4
#
#
# X..
# ..O
# O.X
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  3
#
#
# X..
# O.O
# O.X
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# .O.
# O.X
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  4
#
#
# OX.
# ...
# .X.
# player 1 value:  4.0 policy:  4
# player 2 value:  72.0 policy:  8
#
#
# OO.
# X..
# XOX
# player 1 value:  16.0 policy:  5
# player 2 value:  8.0 policy:  2
#
#
# OO.
# X.X
# XOX
# player 1 value:  8.0 policy:  2
# player 2 value:  8.0 policy:  2
#
#
# .XX
# ...
# OXO
# player 1 value:  8.0 policy:  0
# player 2 value:  32.0 policy:  5
#
#
# .X.
# ..O
# OXO
# player 1 value:  28.0 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# .XX
# ..O
# OXO
# player 1 value:  8.0 policy:  0
# player 2 value:  16.0 policy:  4
#
#
# .XX
# .OO
# OXO
# player 1 value:  12.0 policy:  3
# player 2 value:  8.0 policy:  0
#
#
# ...
# O..
# X.X
# player 1 value:  4.0 policy:  7
# player 2 value:  8.0 policy:  4
#
#
# .X.
# X.O
# OXO
# player 1 value:  4.0 policy:  4
# player 2 value:  20.0 policy:  4
#
#
# .XX
# XOO
# OXO
# player 1 value:  4.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# OX.
# .XO
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  3
#
#
# OX.
# OXO
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  2.0 policy:  2
#
#
# .XO
# O..
# .XX
# player 1 value:  8.0 policy:  4
# player 2 value:  16.0 policy:  6
#
#
# .XO
# O..
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  0
#
#
# .X.
# XOO
# OXO
# player 1 value:  8.0 policy:  2
# player 2 value:  8.0 policy:  0
#
#
# X..
# .O.
# .XO
# player 1 value:  8.0 policy:  2
# player 2 value:  48.0 policy:  2
#
#
# ..X
# .O.
# .XO
# player 1 value:  8.0 policy:  0
# player 2 value:  12.0 policy:  1
#
#
# .O.
# XO.
# .XO
# player 1 value:  8.0 policy:  6
# player 2 value:  4.0 policy:  0
#
#
# ...
# XOO
# .XO
# player 1 value:  8.0 policy:  0
# player 2 value:  8.0 policy:  0
#
#
# .O.
# XO.
# XXO
# player 1 value:  4.0 policy:  0
# player 2 value:  20.0 policy:  2
#
#
# .OO
# XO.
# XXO
# player 1 value:  12.0 policy:  5
# player 2 value:  8.0 policy:  0
#
#
# .OO
# XOX
# XXO
# player 1 value:  4.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# OX.
# .O.
# OXX
# player 1 value:  8.0 policy:  5
# player 2 value:  8.0 policy:  2
#
#
# OX.
# .OX
# OXX
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  2
#
#
# .O.
# .O.
# XXO
# player 1 value:  16.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# ..O
# .O.
# XXO
# player 1 value:  16.0 policy:  0
# player 2 value:  8.0 policy:  0
#
#
# OXX
# ..O
# ..O
# player 1 value:  8.0 policy:  7
# player 2 value:  4.0 policy:  4
#
#
# OXX
# ..O
# .XO
# player 1 value:  4.0 policy:  4
# player 2 value:  20.0 policy:  3
#
#
# OXX
# O.O
# .XO
# player 1 value:  12.0 policy:  6
# player 2 value:  8.0 policy:  4
#
#
# XO.
# .O.
# XXO
# player 1 value:  4.0 policy:  3
# player 2 value:  32.0 policy:  5
#
#
# .X.
# ..O
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  32.0 policy:  4
#
#
# OX.
# ..O
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  3
#
#
# .XO
# ..O
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# ...
# OOX
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  1
#
#
# X.O
# .O.
# XXO
# player 1 value:  4.0 policy:  3
# player 2 value:  20.0 policy:  1
#
#
# ..O
# XO.
# XXO
# player 1 value:  4.0 policy:  0
# player 2 value:  24.0 policy:  1
#
#
# O..
# .XX
# OXO
# player 1 value:  8.0 policy:  1
# player 2 value:  36.0 policy:  1
#
#
# .O.
# .XX
# OXO
# player 1 value:  4.0 policy:  3
# player 2 value:  16.0 policy:  0
#
#
# ...
# OXX
# OXO
# player 1 value:  4.0 policy:  1
# player 2 value:  4.0 policy:  0
#
#
# OXO
# .OX
# XOX
# player 1 value:  2.0 policy:  3
# player 2 value:  2.0 policy:  3
#
#
# OX.
# OOX
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  2.0 policy:  2
#
#
# ...
# OO.
# X.X
# player 1 value:  4.0 policy:  7
# player 2 value:  4.0 policy:  5
#
#
# ...
# O.X
# XOX
# player 1 value:  4.0 policy:  2
# player 2 value:  16.0 policy:  1
#
#
# .O.
# ..X
# OOX
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  4
#
#
# .O.
# .XX
# ..O
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  7
#
#
# .O.
# .XX
# .OO
# player 1 value:  4.0 policy:  3
# player 2 value:  4.0 policy:  6
#
#
# .OO
# ...
# X..
# player 1 value:  8.0 policy:  8
# player 2 value:  4.0 policy:  0
#
#
# ..O
# .X.
# X.O
# player 1 value:  8.0 policy:  7
# player 2 value:  4.0 policy:  5
#
#
# ..O
# .X.
# XXO
# player 1 value:  4.0 policy:  1
# player 2 value:  4.0 policy:  5
#
#
# XOO
# .O.
# XXO
# player 1 value:  4.0 policy:  3
# player 2 value:  4.0 policy:  5
#
#
# XO.
# OO.
# XXO
# player 1 value:  8.0 policy:  2
# player 2 value:  4.0 policy:  5
#
#
# XO.
# .OO
# XXO
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  2
#
#
# OO.
# .XX
# OXO
# player 1 value:  4.0 policy:  3
# player 2 value:  8.0 policy:  2
#
#
# .OX
# .OO
# XXO
# player 1 value:  8.0 policy:  3
# player 2 value:  8.0 policy:  0
#
#
# ...
# .OX
# OXX
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# OX.
# ...
# O.X
# player 1 value:  8.0 policy:  7
# player 2 value:  4.0 policy:  3
#
#
# OX.
# ...
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  44.0 policy:  2
#
#
# OXO
# ...
# OXX
# player 1 value:  4.0 policy:  4
# player 2 value:  8.0 policy:  3
#
#
# .OX
# XOO
# XXO
# player 1 value:  4.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# ..O
# O.X
# OXX
# player 1 value:  16.0 policy:  4
# player 2 value:  8.0 policy:  0
#
#
# ..O
# OXX
# OXX
# player 1 value:  8.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# X.O
# .O.
# .XO
# player 1 value:  8.0 policy:  6
# player 2 value:  8.0 policy:  5
#
#
# X..
# OO.
# .XO
# player 1 value:  8.0 policy:  2
# player 2 value:  4.0 policy:  5
#
#
# X..
# .OO
# .XO
# player 1 value:  16.0 policy:  2
# player 2 value:  8.0 policy:  2
#
#
# X..
# .O.
# OXO
# player 1 value:  8.0 policy:  1
# player 2 value:  4.0 policy:  2
#
#
# XX.
# .O.
# OXO
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# .OX
# XO.
# OXO
# player 1 value:  4.0 policy:  5
# player 2 value:  4.0 policy:  0
#
#
# .OX
# XOX
# OXO
# player 1 value:  2.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# ...
# XOO
# XOX
# player 1 value:  4.0 policy:  0
# player 2 value:  4.0 policy:  1
#
#
# OOX
# ..X
# ..O
# player 1 value:  8.0 policy:  6
# player 2 value:  4.0 policy:  4
#
#
# OOX
# ..X
# X.O
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# ...
# O.O
# XXO
# player 1 value:  16.0 policy:  4
# player 2 value:  8.0 policy:  2
#
#
# X.O
# OO.
# XXO
# player 1 value:  4.0 policy:  5
# player 2 value:  4.0 policy:  5
#
#
# XOX
# OO.
# XXO
# player 1 value:  2.0 policy:  5
# player 2 value:  4.0 policy:  5
#
#
# XO.
# OOX
# XXO
# player 1 value:  2.0 policy:  2
# player 2 value:  2.0 policy:  2
#
#
# ...
# XO.
# X.O
# player 1 value:  4.0 policy:  0
# player 2 value:  20.0 policy:  7
#
#
# X..
# XOO
# .XO
# player 1 value:  4.0 policy:  6
# player 2 value:  4.0 policy:  2
#
#
# XOX
# X.O
# ..O
# player 1 value:  4.0 policy:  6
# player 2 value:  16.0 policy:  7
#
#
# XOX
# X.O
# .OO
# player 1 value:  12.0 policy:  4
# player 2 value:  8.0 policy:  4
#
#
# XOX
# XXO
# .OO
# player 1 value:  4.0 policy:  6
# player 2 value:  4.0 policy:  6
#
#
# .OO
# ...
# X.X
# player 1 value:  4.0 policy:  7
# player 2 value:  4.0 policy:  0
#
#
# O.O
# .XX
# OXO
# player 1 value:  8.0 policy:  1
# player 2 value:  8.0 policy:  1
#
#
# X.O
# OOX
# XXO
# player 1 value:  2.0 policy:  1
# player 2 value:  2.0 policy:  1
#
#
# O..
# X..
# .XO
# player 1 value:  8.0 policy:  1
# player 2 value:  28.0 policy:  2
#
#
# OO.
# ..X
# OXX
# player 1 value:  20.0 policy:  4
# player 2 value:  8.0 policy:  2
#
#
# OO.
# .XX
# OXX
# player 1 value:  8.0 policy:  2
# player 2 value:  8.0 policy:  2
#
#
# XO.
# XOX
# OXO
# player 1 value:  2.0 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# ...
# X.X
# OOX
# player 1 value:  8.0 policy:  2
# player 2 value:  16.0 policy:  4
#
#
# ...
# OXO
# XXO
# player 1 value:  8.0 policy:  1
# player 2 value:  4.0 policy:  2
#
#
# X..
# .XO
# XOO
# player 1 value:  8.0 policy:  2
# player 2 value:  12.0 policy:  3
#
#
# X..
# OXO
# XOO
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# .X.
# ..X
# OOX
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  4
#
#
# XX.
# .OO
# OXX
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  2
#
#
# ..X
# O..
# .OX
# player 1 value:  67.99999999976535 policy:  0
# player 2 value:  16.0 policy:  4
#
#
# ..X
# OO.
# .OX
# player 1 value:  19.9999999977299 policy:  0
# player 2 value:  8.0 policy:  1
#
#
# X.X
# O..
# .OX
# player 1 value:  12.0 policy:  1
# player 2 value:  15.99999996740371 policy:  4
#
#
# .XX
# O..
# .OX
# player 1 value:  8.0 policy:  0
# player 2 value:  8.0 policy:  6
#
#
# ..X
# OX.
# .OX
# player 1 value:  11.999999999997272 policy:  0
# player 2 value:  7.999999997788109 policy:  6
#
#
# X.X
# OO.
# .OX
# player 1 value:  7.999999999970896 policy:  1
# player 2 value:  7.999999999534339 policy:  1
#
#
# OXO
# ..X
# .XO
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# OXO
# ...
# XXO
# player 1 value:  12.0 policy:  3
# player 2 value:  8.0 policy:  4
#
#
# OXX
# O.O
# XXO
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# ...
# .XO
# X..
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  8
#
#
# ...
# .XO
# X.O
# player 1 value:  4.0 policy:  2
# player 2 value:  4.0 policy:  2
#
#
# X..
# OX.
# XOO
# player 1 value:  4.0 policy:  2
# player 2 value:  8.0 policy:  5
#
#
# .XX
# O..
# OOX
# player 1 value:  8.0 policy:  0
# player 2 value:  4.0 policy:  0
#
#
# XXO
# ..O
# .OX
# player 1 value:  4.0 policy:  4
# player 2 value:  7.999999999999998 policy:  6
#
#
# XXO
# ..O
# OOX
# player 1 value:  4.0 policy:  4
# player 2 value:  4.0 policy:  4
#
#
# ..X
# OX.
# OOX
# player 1 value:  7.999999999998181 policy:  0
# player 2 value:  3.999999999970896 policy:  0
